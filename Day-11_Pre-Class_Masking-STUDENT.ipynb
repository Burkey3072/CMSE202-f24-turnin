# %% [markdown]
# # Day 11 Pre-class Assignment: Normal Distributions, Masking, and Log Plots
#
# <img src="https://cdn.scribbr.com/wp-content/uploads/2020/10/standard-normal-distribution.png" width="600px" align="left">
# <img src="https://cf.ltkcdn.net/costumes/images/std-xs/96214-283x424-Phantommask2.webp" width="200px" align="right">

# %% [markdown]
# ### <p style="text-align: right;"> &#9989; Joseph Burke</p>

# %% [markdown]
# ## Goals for today's pre-class assignment
#
# * Working with the descriptive statistics and visualizations of Normal Distributions
# * Practice using masks with NumPy arrays
# * Interpreting Log Plots
#
#
# ## Assignment instructions
#
# **This assignment is due by 11:59 p.m. the day before class,** and should be uploaded into the appropriate "Pre-class assignments" submission folder.  If you run into issues with your code, make sure to use Slack to help each other out and receive some assistance from the instructors. Submission instructions can be found at the end of the notebook.

# %% [markdown]
# ---
# ## 1. Normal Distributions
# In today’s assignment we will be talking about the **Normal** (or Gaussian) **distribution.** A normal distribution of values looks something like this:

# %%
# Import necessary libraries for data visualization and numerical operations
import matplotlib.pyplot as plt
import numpy as np

# Define the number of data points
N_points = 100000
# Specify the mean of the normal distribution
mean = 10.0
# Specify the standard deviation of the normal distribution
stand_dev = 1.0

# Define the number of bins for the histogram
n_bins = 20

# Generate a normal distribution of N_points with the specified mean and standard deviation
x = np.random.normal(mean, stand_dev, N_points)

# Plot a histogram of the generated data points with the specified number of bins
plt.hist(x, bins=n_bins)

# Add labels to the x-axis and y-axis
plt.xlabel('Value')  # X-axis label indicating the value of the data points
plt.ylabel('Frequency')  # Y-axis label indicating the frequency of data points within each bin

# Display the plot
plt.show()

# %% [markdown]
# Which you may have seen before (it’s also called a *bell curve*). Normal distributions are very important in statistics, primarily because **most distributions eventually become Normal distributions if you collect enough samples** (this is called the Central Limit Theorem).

# %% [markdown]
# ### 1.1
# Change the number of data points (`N_points`) and plot the resulting distribution. Make four subplots (using `plt.subplot()`), showing distributions for `N_points`= 10, 100, 1000, and 10000. (Use `mean`=10.0  and `stand_dev` = 1.0)

# %%
# Insert your code here
def norm (mean=10,stdev=1,npoints=[1,10,100,1000,10000,1000000],nbins=20):
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    plt.xlabel('Value')  
    plt.ylabel('Frequency') 
    plt.tight_layout()
    
    longest = 1
    if type(mean)==list:
        if longest<len(mean):
            longest = len(mean)
            for i in range(longest):
                plt.subplot(int(round(longest/2,0)),int(round(longest/2,0)),i+1)
                x = np.random.normal(mean[i], stdev, npoints)
                plt.hist(x, bins=nbins)
                plt.title(str(mean[i])+' Mean')
                
    elif type(stdev)==list:
        if longest<len(stdev):
            longest = len(stdev)
            for i in range(longest):
                plt.subplot(int(round(longest/2,0)),int(round(longest/2,0)),i+1)
                x = np.random.normal(mean, stdev[i], npoints)
                plt.hist(x, bins=nbins)
                plt.title(str(stdev[i])+' Standard Deviation') 

    elif type(npoints)==list:
        if longest<len(npoints):
            longest = len(npoints)
            for i in range(longest):
                plt.subplot(int(round(longest/2,0)),int(round(longest/2,0)),i+1)
                x = np.random.normal(mean, stdev, npoints[i])
                plt.hist(x, bins=nbins)
                plt.title(str(npoints[i])+' Points')

    elif type(nbins)==list:
        if longest<len(nbins):
            longest = len(nbins)
            for i in range(longest):
                plt.subplot(int(round(longest/2,0)),int(round(longest/2,0)),i+1)
                x = np.random.normal(mean, stdev, npoints)
                plt.hist(x, bins=nbins[1])
                plt.title(str(nbins[i])+' Bins')
    else:
        x = np.random.normal(mean, stdev, npoints)
        plt.hist(x, bins=nbins)
            
    plt.show()
    plotting=':)'
    return plotting

histogram = norm()
histogram
# Out:
# C:\Users\Joseph Burke\AppData\Local\Temp\ipykernel_12344\2832688526.py:33: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(int(round(longest/2,0)),int(round(longest/2,0)),i+1)
# ':)'

# %% [markdown]
# ### 1.2
# What do you notice about how the shape of the distribution changes as you use more data points?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *The distribution becomes shaped more like the bell curve*

# %% [markdown]
# ### 1.3
# Run your code above again, so you get a new set of data points for your plots. What do you notice about how the different plots change when you pick new data points?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *The first graphs look much different from what they were previously, but the larger data sets barely changed*

# %% [markdown]
# Let’s talk about the important properties of a Normal distribution.
#
# ### 1.4 Mean & Median
# Make four distributions (using `N_points` = 100000 and `stand_dev`=1.0) with means of 0.0, 1.0, 5.0, 10.0. For each distribution, calculate the mean and median values.

# %%
# Insert your code here
meanslist=[0.0,1.0,5.0,10.0]
norm(mean=meanslist,npoints=100000,stdev=1.0)
# Out:
# C:\Users\Joseph Burke\AppData\Local\Temp\ipykernel_12344\2832688526.py:15: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(int(round(longest/2,0)),int(round(longest/2,0)),i+1)
# ':)'

# %% [markdown]
# ### 1.5
# What do you notice about the mean and median values for the four distributions? How do they compare to one another?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *For each graph, the mean and median are the same number at the given mean*

# %% [markdown]
# ### 1.6 Standard Deviation
# Make four distributions (using `N_points` = 100000 and `mean`=10.0) with standard deviations of 0.5, 1.0, 5.0, and 10.0. Make four subplots showing each of the distributions.

# %%
# Insert your code here
stdevlist=[.5,1.0,5.0,10.0]
plt.xlim=[-40,40]
norm(npoints=100000,mean=10,stdev=stdevlist)
# Out:
# C:\Users\Joseph Burke\AppData\Local\Temp\ipykernel_12344\2832688526.py:24: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(int(round(longest/2,0)),int(round(longest/2,0)),i+1)
# ':)'

# %% [markdown]
# ### 1.7
# What do you notice about the shape of the five distributions? How do they compare to one another? What effect does changing the standard deviation have on the distributions? **NOTE: If you don't notice a difference right away, try setting `xlim` to $[-40,40]$ for each subplot**

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *The larger the standard deviation, the wider, flatter and more spread out the bell curve gets.*

# %% [markdown]
# ---
# ## 2. Masking
#
# Masking is an extremely important and absurdly useful tool that we will be adding to our coding tool box. Fundamentally, **"masking" is a process that allows us to select specific parts of our data that meet some condition.** Let’s work through some examples, to better understand what this means.
#
# Let’s start by looking at the random set of numbers.

# %%
vals = np.array([3, 11, 6, 9, 7, 12, 8, 11, 5, 3, 15, 13])

# %% [markdown]
# ### 2.1
# Write a piece of code that uses a `for` loop and an `if` statement to identify all values of `vals` that are above 8. Append the values that meet this condition to a new list and print them out.

# %%
# Insert your code here
list8=[]
for i in range(len(vals)): 
    if vals[i]>8:
        list8.append(vals[i])
print(list8)
# Out:
# [11, 9, 12, 11, 15, 13]

# %% [markdown]
# What we just did was select a subset of our data; specifically, all values in `vals` greater than 8. Now, let’s do the same thing using *masking*. The code below creates a mask and then uses that mask to select all of the data points that meet our condition.

# %%
mask = vals > 8
vals_masked = vals[mask]

# %% [markdown]
# ### 2.2
# Let’s break this code down, piece by piece. First, write a piece of code that prints `mask`.

# %%
# Insert your code here
print(mask)
# Out:
# [False  True False  True False  True False  True False False  True  True]

# %% [markdown]
# ### 2.3
# You should see a list of Boolean values (`True` or `False`). Compare your `mask` values to the values of `vals`. What do you notice?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *Each boolean lines up with the order of the values in the list, and are true when the condition is met*

# %% [markdown]
# ### 2.4
# Now print out the values of `vals_masked`.

# %%
# Insert your code here
print(vals_masked)
# Out:
# [11  9 12 11 15 13]

# %% [markdown]
# ### 2.5
#
# What values does `vals_masked` contain? How are these values connected to `vals`, `mask`, and the list that you created in 2.1?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *All of the values in the list vals greater than 8, and the indexes match with the trues of mask*

# %% [markdown]
# ### 2.6
# Try tinkering with the mask generation code (line 1 from the cell in 2.1) by changing the condition (e.g., values below 8, values above 11, etc.). Print out the `mask` and `vals_masked` values for each one to convince yourself that the "masks" you create match your expectations.

# %%
# Insert code here
mask = (vals < 5) #and vals >8)
vals_masked = vals[mask]
print(mask)
print(vals_masked)
# Out:
# [ True False False False False False False False False  True False False]
# [3 3]

# %% [markdown]
# ### 2.7
# Take a moment and reflect. What is a mask? What does the process of masking data or values do?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *masking creates an easy, loopless way to sort through lists for specific conditions, and return a list matching with the values that satisffy the condition*

# %% [markdown]
# ### 2.8
# Before moving on, explain the concept of masking as if you were talking to someone who has never coded before.

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *If we wanted to sort through a pocket of many things and slowly take everything out one by one see if its red, and put it in our other pocket, that takes awhile.  Mask would be like pulling everything out of your pocket, giving it a quick glance, and all the red objects glow while all the other objects pale *

# %% [markdown]
# ---
# ## 3. Interpreting Log Plots
#
# For this next exercise, we will explore the utility and interpretation of **log plots**. We’re quite used to **linear plots** at this point; these are plots where the space between 1 and 2 is the same as it is between 3 and 4 (or 8 and 9 or 800 and 801). The step size is linear, hence the name.
#
# In a log plot, though, the space between 1 and 2 is the same as the space between 2 and 4 (or 4 and 8 or 800 and 1600). In a log plot, the step size is *multiplicative* (e.g., all of the previous examples increased by a factor of 2).
#
# Log plots are useful when you have a **large dynamic range.** That is, when the difference between the smallest thing you care about and the largest thing you care about is **BIG.**
#
# Let’s take another look at the economic data you explored in a previous in-class assignment. The filename is `GDP_Cleaned.csv`, and you can find it on the course website. (as the name suggests, we’ve cleaned up the dataset for you compared to the one you worked with in class).

# %% [markdown]
# ### 3.1
# Use Pandas to read in `GDP_Cleaned.csv` and then display the first few lines (remember which Pandas function does that?)

# %%
# Write your code here
gdp_cleaned = pd.read_csv('GDP_Cleaned.csv')
gdp_cleaned
# Out:
#     Year  Africa Eastern and Southern  Africa Western and Central  \
# 0   1960                 1.929193e+10                1.040732e+10
# 1   1961                 1.970186e+10                1.113130e+10
# 2   1962                 2.147035e+10                1.194684e+10
# 3   1963                 2.570500e+10                1.268022e+10
# 4   1964                 2.350165e+10                1.384262e+10
# ..   ...                          ...                         ...
# 56  2016                 8.547519e+11                6.874847e+11
# 57  2017                 9.622690e+11                6.809891e+11
# 58  2018                 9.840320e+11                7.381313e+11
# 59  2019                 9.778092e+11                7.920789e+11
# 60  2020                 8.984741e+11                7.865850e+11
#
#        Australia       Austria       Burundi       Belgium         Benin  \
# 0   1.857767e+10  6.592694e+09  1.960000e+08  1.165872e+10  2.261956e+08
# 1   1.965282e+10  7.311750e+09  2.030000e+08  1.240015e+10  2.356682e+08
# 2   1.989249e+10  7.756110e+09  2.135000e+08  1.326402e+10  2.364349e+08
# 3   2.150745e+10  8.374175e+09  2.327500e+08  1.426002e+10  2.539276e+08
# 4   2.376414e+10  9.169984e+09  2.607500e+08  1.596011e+10  2.698190e+08
# ..           ...           ...           ...           ...           ...
# 56  1.208847e+12  3.955686e+11  2.959641e+09  4.757396e+11  1.182107e+10
# 57  1.329188e+12  4.162073e+11  3.172292e+09  5.015229e+11  1.270166e+10
# 58  1.432881e+12  4.548726e+11  3.036937e+09  5.434107e+11  1.425099e+10
# 59  1.396567e+12  4.450754e+11  3.012309e+09  5.332545e+11  1.439169e+10
# 60  1.330901e+12  4.289654e+11  3.258187e+09  5.153325e+11  1.565155e+10
#
#     Burkina Faso    Bangladesh  ...        Turkey        Uganda  \
# 0   3.304428e+08  4.274894e+09  ...  1.399507e+10  4.230084e+08
# 1   3.502472e+08  4.817580e+09  ...  7.988889e+09  4.415241e+08
# 2   3.795670e+08  5.081413e+09  ...  8.922222e+09  4.490126e+08
# 3   3.940406e+08  5.319458e+09  ...  1.035556e+10  5.161478e+08
# 4   4.103216e+08  5.386055e+09  ...  1.117778e+10  5.890566e+08
# ..           ...           ...  ...           ...           ...
# 56  1.283336e+10  2.214152e+11  ...  8.696930e+11  2.907859e+10
# 57  1.410696e+10  2.497109e+11  ...  8.589963e+11  3.074447e+10
# 58  1.605991e+10  2.740390e+11  ...  7.783770e+11  3.291234e+10
# 59  1.599080e+10  3.025634e+11  ...  7.614282e+11  3.517004e+10
# 60  1.736906e+10  3.242392e+11  ...  7.201012e+11  3.737203e+10
#
#     Upper middle income       Uruguay  United States  \
# 0          2.379344e+11  1.242289e+09   5.433000e+11
# 1          2.133097e+11  1.547389e+09   5.633000e+11
# 2          2.238717e+11  1.710004e+09   6.051000e+11
# 3          2.333284e+11  1.539681e+09   6.386000e+11
# 4          2.686296e+11  1.975702e+09   6.858000e+11
# ..                  ...           ...            ...
# 56         1.979362e+13  5.723665e+10   1.874508e+13
# 57         2.191199e+13  6.423397e+10   1.954298e+13
# 58         2.358090e+13  6.451504e+10   2.061186e+13
# 59         2.397975e+13  6.123115e+10   2.143322e+13
# 60         2.310488e+13  5.362883e+10   2.093660e+13
#
#     St. Vincent and the Grenadines         World  South Africa        Zambia  \
# 0                     1.306656e+07  1.384628e+12  7.575397e+09  7.130000e+08
# 1                     1.399988e+07  1.440342e+12  7.972997e+09  6.962857e+08
# 2                     1.452488e+07  1.545697e+12  8.497997e+09  6.931429e+08
# 3                     1.370822e+07  1.665141e+12  9.423396e+09  7.187143e+08
# 4                     1.475821e+07  1.824117e+12  1.037400e+10  8.394286e+08
# ..                             ...           ...           ...           ...
# 56                    7.744296e+08  7.641725e+13  2.963573e+11  2.095841e+10
# 57                    7.921778e+08  8.132672e+13  3.495541e+11  2.587360e+10
# 58                    8.113000e+08  8.634351e+13  3.682889e+11  2.631164e+10
# 59                    8.247185e+08  8.760777e+13  3.514316e+11  2.330869e+10
# 60                    8.096815e+08  8.470543e+13  3.019236e+11  1.932005e+10
#
#         Zimbabwe
# 0   1.052990e+09
# 1   1.096647e+09
# 2   1.117602e+09
# 3   1.159512e+09
# 4   1.217138e+09
# ..           ...
# 56  2.054868e+10
# 57  1.901533e+10
# 58  1.952362e+10
# 59  1.693243e+10
# 60  1.676851e+10
#
# [61 rows x 122 columns]

# %% [markdown]
# ### 3.2
# Make a plot of the GDP versus time (Year) for both the United States and Bangladesh.

# %%
# Write your code here
plt.plot(gdp_cleaned['Year'],gdp_cleaned['United States'],color='blue',label='US')
plt.plot(gdp_cleaned['Year'],gdp_cleaned['Bangladesh'],color='orange',label='Bangladesh')
plt.title('US&Bang GDP')
plt.ylabel('GDP')
plt.xlabel('Years')
plt.legend()
plt.grid()
plt.tight_layout()

# %% [markdown]
# ### 3.3
# Based on what you see in this plot, what can you say about the growth of the economy in Bangladesh?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *I can't say much.  It looks like a small increase*

# %% [markdown]
# ### 3.4
# Now remake the same plot, but this time use the `plt.yscale()` function set the y-axis to be logarithmic (i.e. "log") (If you're not sure how to use `plt.yscale()` you should take a look at the documentation).

# %%
#Write your code here
plt.plot(gdp_cleaned['Year'],gdp_cleaned['United States'],color='blue',label='US')
plt.plot(gdp_cleaned['Year'],gdp_cleaned['Bangladesh'],color='orange',label='Bangladesh')
plt.title('US&Bang GDP')
plt.ylabel('GDP')
plt.xlabel('Years')
plt.legend()
plt.grid()
plt.yscale('log')
plt.tight_layout()

# %% [markdown]
# ### 3.5
# Using the log-plot, what can you say about the growth of the economy in Bangladesh? Use the plot to read off the starting and ending values (i.e., the economy of Bangladesh in 1960 and 2021).

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *They seem to be increasing at a similar rate linearly according to this graph*

# %% [markdown]
# ### 3.6
# Now try setting `xscale` to be log as well using `plt.xscale()`.

# %%
# Write your code here
plt.yscale('log')
plt.xscale('log')
plt.plot(gdp_cleaned['Year'],gdp_cleaned['United States'],color='blue',label='US')
plt.plot(gdp_cleaned['Year'],gdp_cleaned['Bangladesh'],color='orange',label='Bangladesh')
plt.title('US&Bang GDP')
plt.ylabel('GDP')
plt.xlabel('Years')
plt.legend()
plt.grid()
plt.tight_layout()

# %% [markdown]
# ### 3.7
# What do you notice? How large is the dynamic range of the x-axis values (i.e., by what multiplicative value does the x-values increase?)
#
# Does it make sense to use a log-scale on the x-axis?

# %% [markdown]
# <font size="+3" color="green">&#9998;</font> *The dynamic range for this graph is not visually apparent for some reason.  It does not make sense to use a log scale for this relation of time*

# %% [markdown]
# ---
# ## Follow-up Questions
#
# Copy and paste the following questions into the appropriate box in the assignment survey include below and answer them there. (Note: You'll have to fill out the section number and the assignment number and go to the "NEXT" section of the survey to paste in these questions.)
#
# 1. In your own words, what does the standard deviation tells us about the shape of the distribution of values when the standard deviation is small versus large?
#
# 2. In your own words, explain why we might use a "mask" when working with data.
#
# 3. When visualizing data, when might it make sense to use a logarithmic ("log") scale?

# %% [markdown]
# ---
# ## Assignment wrap-up
#
# Please fill out the form that appears when you run the code below.  **You must completely fill this out in order to receive credit for the assignment!**

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://cmse.msu.edu/cmse201-pc-survey" 
	width="800px" 
	height="600px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)
# Out:
# <iframe
# 	src="https://cmse.msu.edu/cmse201-pc-survey"
# 	width="800px"
# 	height="600px"
# 	frameborder="0"
# 	marginheight="0"
# 	marginwidth="0">
# 	Loading...
# </iframe>

# %% [markdown]
# ### Congratulations, you're done!
#
# Submit this assignment by uploading it to the course Desire2Learn web page.  Go to the "Pre-class assignments" folder, find the appropriate submission link, and upload it there.
#
# See you in class!

# %% [markdown]
# &#169; Copyright 2023,  The Department of Computational Mathematics, Science and Engineering.
